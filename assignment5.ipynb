# %% [markdown]
# q1.Explain pandas and its role in Data Analysis and Machine Learning.
# Ans. Pandas is a Python library used for data manipulation and analysis.
# Role in Data Analysis:-
# Read and write data (CSV, Excel, etc.).
# Clean and preprocess data.
# Filter, sort, and group data.
# Perform statistical analysis and summarize information
# Role in Machine Learning:-
# Load datasets.
# Handle missing values and encode categorical data.
# Perform Exploratory Data Analysis (EDA).
# Select features and prepare data for machine learning models.
# Works seamlessly with libraries like NumPy and Scikit-learn.

# %% [markdown]
# Q2.Differentiate between:
# ● Series and DataFrame
# Series
# A one-dimensional labeled array in Pandas.
# Can store data of any type (integer, float, string, etc.).
# Similar to a single column in a table.
# DataFrame
# A two-dimensional tabular data structure with rows and columns.
# Similar to an Excel spreadsheet or database table.
# Can contain different data types in different columns.
#
# ● loc[] and iloc[] functions in Pandas
# loc[] (Label-based Indexing)
# Used to access rows and columns by labels (names).
# iloc[] (Integer-based Indexing)
# Used to access rows and columns by integer positions.

# %%
pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/eb/62/c321f13b5ba1819fc8dca456c7fce578da2dcfecff1abbf0eaddf8406c0f/pandas-3.0.3-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tzdata from https://files.pythonhosted.org/packages/ce/e4/dccd7f47c4b64213ac01ef921a1337ee6e30e8c6466046018326977efd95/tzdata-2026.2-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB 660.6 kB/s eta 0:00:15
#    ---------------------------------------- 0.0/9.9 MB 393.8 kB/s eta 0:00:26
#    ---------------------------------------- 0.1/9.9 MB 508.4 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/9.9 MB 525.1 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/9.9 MB 481.4 kB/s eta 0:00:21
# ...

# %%
# Q3.
import pandas as pd

# Create DataFrame
data = {
    "Name": ["Amit", "Neha", "Rahul", "Sneha"],
    "Age": [20, 21, 19, 22],
    "Marks": [85, 90, 78, 88]
}

df = pd.DataFrame(data)

# Display the DataFrame
print("Original DataFrame:")
print(df)

# Display first 2 rows
print("\nFirst 2 Rows:")
print(df.head(2))

# Display only Name and Marks columns
print("\nName and Marks Columns:")
print(df[["Name", "Marks"]])

# Add a new column named "Result"
df["Result"] = ["Pass", "Pass", "Pass", "Pass"]

print("\nDataFrame with Result Column:")
print(df)

# Display students with marks greater than 80
print("\nStudents with Marks > 80:")
print(df[df["Marks"] > 80])
# Out:
# Original DataFrame:
#     Name  Age  Marks
# 0   Amit   20     85
# 1   Neha   21     90
# 2  Rahul   19     78
# 3  Sneha   22     88
#
# First 2 Rows:
#    Name  Age  Marks
# 0  Amit   20     85
# 1  Neha   21     90
#
# Name and Marks Columns:
#     Name  Marks
# 0   Amit     85
# 1   Neha     90
# 2  Rahul     78
# 3  Sneha     88
#
# DataFrame with Result Column:
#     Name  Age  Marks Result
# 0   Amit   20     85   Pass
# 1   Neha   21     90   Pass
# 2  Rahul   19     78   Pass
# 3  Sneha   22     88   Pass
#
# Students with Marks > 80:
#     Name  Age  Marks Result
# 0   Amit   20     85   Pass
# 1   Neha   21     90   Pass
# 3  Sneha   22     88   Pass

# %%
# Q4. 
import pandas as pd
import numpy as np

# Create DataFrame
data = {
    "Name": ["A", "B", "C", "D"],
    "Age": [25, np.nan, 27, 24],
    "Salary": [30000, 40000, np.nan, 35000]
}

df = pd.DataFrame(data)

# Identify missing values
print("Missing Values:")
print(df.isnull())

# Fill missing Age with average age
df["Age"].fillna(df["Age"].mean(), inplace=True)

# Fill missing Salary with median salary
df["Salary"].fillna(df["Salary"].median(), inplace=True)

# Display cleaned dataset
print("\nCleaned Dataset:")
print(df)
# Out:
# Missing Values:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2  False  False    True
# 3  False  False   False
#
# Cleaned Dataset:
#   Name   Age   Salary
# 0    A  25.0  30000.0
# 1    B   NaN  40000.0
# 2    C  27.0      NaN
# 3    D  24.0  35000.0
# C:\Users\asus\AppData\Local\Temp\ipykernel_3900\1671759978.py:19: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# ...
